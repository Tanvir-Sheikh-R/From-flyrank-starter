# %%
class Solution:
    def maxArea(self, heights: List[int]) -> int:

# %%
h = [1,7,2,5,4,7,3,6]
rev = h[::-1]

max_val = 0
for i in range(len(h)):
    second_tall = 0
    for j in range(len(h)):

        if rev[j] <= second_tall:
            continue

        back = len(h) - j -1
        weight = back - i

        if weight < 1:
            continue

        max_val = max(min(h[i], rev[j]) * weight, max_val)
        second_tall = rev[j]


max_val
# Out:
# 36

# %%
print(f"Min from {val}, {rev[i]}, * weight{weight}, then compare max, {max}")
# Out:
# [6, 3, 7, 4, 5, 2, 7, 1]

# %%
print(range(2))
# Out:
# range(0, 2)

# %%
h = [1,7,2,5,4,7,3,6]

max_val = 0
left = 0
right = len(h) - 1

while left < right:
    weight = right - left
    max_val = max(min(h[left], h[right]) * weight, max_val)


    if h[left] < h[right]:
        left += 1

    else:
        right -= 1

print(max_val)
# Out:
# 36
