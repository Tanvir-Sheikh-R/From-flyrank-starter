# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tanvir-Sheikh-R/From-flyrank-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Lane 2 — Refresh / Content Opportunity Scoring
#
# I am choosing the Refresh / Content Opportunity Scoring lane because it connects the available search and engagement data to a concrete content decision: which pages should be reviewed first. The starter dataset contains observable signals such as impressions, clicks, sessions, CTR, average position, content age, freshness, and engagement metrics. I want to investigate whether these signals can support a ranked review queue that helps a content team prioritize pages for refresh, expansion, protection, pruning, or monitoring. This is more useful than simply training a model because the final goal is a practical, evidence-based prioritization of limited editorial time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2 Decide which pages should receive editorial review first.
# Which pages should be reviewed first for a possible content refresh or other intervention, based on observable search performance, engagement, freshness, and content characteristics?
#
# Who acts: A content strategist, SEO specialist, or editor reviews the ranked pages.
#
# Action: Based on the evidence and reason codes, the reviewer may refresh, expand, protect, prune, or monitor a page. The system will recommend which pages deserve attention; it will not automatically decide that a page must be changed.
#
# Cost of a wrong call: A false positive can waste limited editorial time on a page that did not need attention. A false negative can cause an important page with declining or weak performance to be missed. Because review capacity is limited, I will focus on ranking quality, especially Precision@K, rather than treating every page equally.
#
# Why data/ML can help: A simple rule can identify obvious cases such as stale pages or low-CTR pages, but pages can have many signals at the same time. A model may help rank the most promising review candidates when the patterns are difficult to express with a few fixed rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nMedian impressions_90d:",
      df["impressions_90d"].median())

print("Median sessions_90d:",
      df["sessions_90d"].median())

print("Declining pages (%):",
      (df["trend_direction"].eq("down").mean() * 100).round(2))
# Out:
# Rows: 30000
# Columns: 44
#
# Median impressions_90d: 731.0
# Median sessions_90d: 7.0
# Declining pages (%): 54.21

# %% [markdown]
# ## 4
# ### What I can claim
# I can measure associations between observable content/search signals and page performance in this dataset. I can build a ranking or scoring system that provides directional, decision-support recommendations for which pages deserve human review first. I can compare the ranking against a simple baseline using metrics such as Precision@K.
#
# ### What I cannot claim
# I cannot claim that any individual signal causes a page to rank better or worse in Google. I cannot claim that refreshing a recommended page will definitely improve its traffic or ranking because the available data is observational rather than experimental. I also cannot claim that the starter result will generalize to all websites or to the full warehouse without further validation. The starter trend_direction label is a current-window proxy, so a stronger future version should define an outcome in a later time window and carefully check for leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
