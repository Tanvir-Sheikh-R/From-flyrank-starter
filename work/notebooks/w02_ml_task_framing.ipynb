# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tanvir-Sheikh-R/From-flyrank-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# This is fundamentally binary classification (declining vs. not), whose output — a predicted probability — I use as a score to rank pages. It's not clustering (I already have a defined outcome to predict, not an unlabeled grouping problem), and not pure ranking (there's no pairwise preference data — I'm scoring individual pages independently, then sorting by score).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# The target is a proxy, not a direct measurement: is_declining_label = 1 when trend_direction == "down", i.e. impressions dropped more than 20% comparing the last 30 days to the prior 30. It's a proxy for "needs review," not a direct quality signal — a drop could come from seasonality or a SERP change, not a content problem. trend_direction and trend_pct are the label source, so I exclude both from features entirely (data dictionary flags this explicitly as leakage).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# Precision@50 — of my top 50 ranked pages, what fraction are actually declining. I'm picking precision over recall/accuracy because review capacity is the real constraint: a wrong page in my top 50 wastes a reviewer's limited time (costly), while a missed declining page outside the top 50 can still surface next cycle (cheaper). The starter pipeline's own baseline-to-model jump (~0.24 → ~0.74 on this metric) is the benchmark I'm aiming to reproduce or beat.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# One row = one content page (content_id), over a trailing 90-day window. content_id/client_id stay in for grouping only (never as features — client_id specifically for a later client-holdout split); provider_used/model_used are dropped per the dictionary; trend_direction/trend_pct are dropped as the label source.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# Two concrete reasons from the dictionary itself: (a) top_3 pages have a median of just 53 impressions in 90 days, so a flat CTR threshold treats small-sample noise as signal — 0% CTR means something different at 50 impressions vs. 5,000; (b) signals interact — a declining page with high search volume and good position is a different priority than one that never had demand, which is exactly the kind of weighted interaction a fixed if/else can't capture but the model's 0.24→0.74 lift demonstrates it does.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✓] Every section above is filled — markdown thinking AND the code that backs it
# - [✓] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✓] No client names, URLs, or private queries anywhere
# - [✓] My claims use careful words: observed, measured, directional, decision-support
# - [✓] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
